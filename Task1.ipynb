# %%
user_name=input("Enter the name:")
age=int(input("Enter the age:"))
hobby=input("Enter the hobby:")
print("Personal Introduction")
print(f"Hello {user_name}")
print(f"{user_name} your age is {age}")
print(f"{user_name} your hobby is {hobby}")
print("We are very happy to welcome you")
# Out:
# Enter the name: Aasmi Nisha
# Enter the age: 22
# Enter the hobby: Reading,Singing
# Personal Introduction
# Hello Aasmi Nisha
# Aasmi Nisha your age is 22
# Aasmi Nisha your hobby is Reading,Singing
# We are very happy to welcome you
